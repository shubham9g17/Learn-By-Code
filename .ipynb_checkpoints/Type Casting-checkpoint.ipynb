# %% [markdown]
# # TYPE CASTING

# %% [markdown]
# ## int()

# %% [markdown]
# We can use this function values from other datatypes to int

# %%
int(123.456)
# Out:
# 123

# %%
int(3+5j)#can't convert complex to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d551f93944dd> in <module>
# ----> 1 int(3+5j)#can't convert complex to int
#
# TypeError: can't convert complex to int

# %%
int(True)
# Out:
# 1

# %%
int("102.45")#when converting str to int make sure it is already in int form
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-fdaa5f6d2b79> in <module>
# ----> 1 int("102.45")#when converting str to int make sure it is already in int form
#
# ValueError: invalid literal for int() with base 10: '102.45'

# %%
int("102")
# Out:
# 102

# %%
int("0b111")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-ec3aa5ae8704> in <module>
# ----> 1 int("0b111")
#
# ValueError: invalid literal for int() with base 10: '0b111'

# %%
int("0b111",2)
# Out:
# 7

# %% [markdown]
# ## float()

# %% [markdown]
# We can use float() function to convert other type values to float type

# %%
float(10)
# Out:
# 10.0

# %%
float(True)
# Out:
# 1.0

# %%
float("10")
# Out:
# 10.0

# %%
float("10.56")
# Out:
# 10.56

# %%
float("0b111.11")#cant work with binary string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-2083ffad16d7> in <module>
# ----> 1 float("0b111.11")#cant work with binary string
#
# ValueError: could not convert string to float: '0b111.11'

# %%
float(10.5+2.3j)#read error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c4ddc4d34703> in <module>
# ----> 1 float(10.5+2.3j)
#
# TypeError: can't convert complex to float

# %% [markdown]
# ## complex()

# %% [markdown]
# We can use this function to convert x into complex number with real part as x and imaginary part as 0

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(9.5)
# Out:
# (9.5+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex("10")
# Out:
# (10+0j)

# %%
complex("0b111")#not complatible with binary form
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-71035ac77167> in <module>
# ----> 1 complex("0b111")#not complatible with binary form
#
# ValueError: complex() arg is a malformed string

# %% [markdown]
# complex(x,y) --> x as real part and y as imaginary part

# %%
complex(10,45)
# Out:
# (10+45j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex("100","23")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-34a85182f95f> in <module>
# ----> 1 complex("100","23")
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,"12")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-acbad339f69f> in <module>
# ----> 1 complex(10,"12")
#
# TypeError: complex() second arg can't be a string

# %%
complex("10",12)# this form only compatible with numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-2b4aeb006fad> in <module>
# ----> 1 complex("10",12)
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# ## bool()

# %% [markdown]
# We can use this function to convert any other datatype to bool type

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool("false")
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(int)
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool("")
# Out:
# False

# %% [markdown]
# ## str()

# %% [markdown]
# We can use this method to convert other type value to str type

# %%
str(10)
# Out:
# '10'

# %%
str(0b111)#which form of int value You give it will always give you result in base 10
# Out:
# '7'

# %%
str(10.345)
# Out:
# '10.345'

# %%
str("10+5j")
# Out:
# '10+5j'

# %%
str(True)
# Out:
# 'True'
